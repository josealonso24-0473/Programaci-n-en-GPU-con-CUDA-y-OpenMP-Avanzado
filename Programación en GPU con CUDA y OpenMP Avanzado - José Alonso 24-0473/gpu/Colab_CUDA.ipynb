# %% [markdown]
# # Suma de vectores en GPU (CUDA)
# Programación Distribuida — José Armando Alonso Polanco (24-0473)
#
# **Antes de correr:** en el menú de arriba ve a `Entorno de ejecución` → `Cambiar tipo de entorno de ejecución` → selecciona **GPU (T4)** → Guardar.

# %%
# Verifica que la GPU esté disponible
# !nvidia-smi

# %%
# %%writefile vector_add_cuda.cu
# // (Pega aquí el contenido de vector_add_cuda.cu si Colab no lo detecta al subir el archivo)

# %%
# Compila con nvcc
# !nvcc -O2 vector_add_cuda.cu -o vector_add_cuda

# %%
# Ejecuta y copia el tiempo reportado para usarlo en el informe
# !./vector_add_cuda

# %%
# Muestra el tiempo guardado en el archivo (para copiar exacto)
# !cat tiempo_gpu.txt
